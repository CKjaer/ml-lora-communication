# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2 as cv
import io

# %%
sampling_rate = 1000000
sample_duration = 0.01
time = np.linspace(0, sample_duration, int(sampling_rate * sample_duration))
amplitude = 1

# generate 1000 sine waves
num_waves = 1000
frequency = np.random.uniform(0, 100000, num_waves)
sine_waves = [np.sin(2 * np.pi * f * time) for f in frequency]

# %%
def generate_fft_plot(input_signal, fig_name):
    fft = np.fft.fft(input_signal)
    fft_modulus = np.abs(fft)

    # getfrequency index
    freqs_idx = np.arange(len(fft_modulus))

    # plt.figure()
    # plt.plot(freqs_idx[:len(freqs_idx)//2], fft_modulus[:len(freqs_idx)//2], color = "black")
    # plt.xlabel('Frequency (Hz)')
    # plt.ylabel('Magnitude')
    # plt.xlim(0, 100000)

    # make a binary image of the modulus plot
    fig= plt.figure(figsize=(2,2))
    plt.axis('off')
    fig.set_facecolor('black')
    plt.plot(freqs_idx[:len(freqs_idx)//2], fft_modulus[:len(freqs_idx)//2], color = "white", antialiased=False, linewidth=1)
    plt.close(fig)
    #fig.canvas.draw()
    fig.savefig(f"data/{fig_name}", bbox_inches='tight', pad_inches=0)


# print(f"Frequency: {frequency[1]}")    
# generate_fft_plot(sine_waves[1], sampling_rate)

# %%
for i in range(10):
    generate_fft_plot(sine_waves[i], f"fft_{i}.png")
